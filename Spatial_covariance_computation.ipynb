# %%
import mne
import numpy as np
import pandas as pd
import os

# %%
for filename in os.listdir():
    if filename.split('.')[-1] == 'edf':
        raw = mne.io.read_raw_edf(filename)
        spatial_cov = np.dot(sample.get_data(), np.transpose(sample.get_data())) / sample.n_times
        newfile_name = '_'.join(filename.split('.')[0].split(' ')) + '_spatial_cov_bin'
        spatial_cov.tofile(newfile_name)
# Out:
# Extracting EDF parameters from E:\Courseware\DeeCamp2021\EEG files\EC datasets\H S1 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from E:\Courseware\DeeCamp2021\EEG files\EC datasets\H S10 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from E:\Courseware\DeeCamp2021\EEG files\EC datasets\H S11 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from E:\Courseware\DeeCamp2021\EEG files\EC datasets\H S13 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from E:\Courseware\DeeCamp2021\EEG files\EC datasets\H S14 EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# ...
